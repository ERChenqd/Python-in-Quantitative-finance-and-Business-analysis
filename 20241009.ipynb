# %%
print("nice")
# Out:
# nice

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
age=19
age
# Out:
# 19

# %%
id(age)
# Out:
# 133585349690160

# %%
age=91
age
# Out:
# 91

# %%
id(age)
# Out:
# 133585349692464

# %%
class Person():
    def __init__(self,age):
        self.age=age

fab=Person(19)
fab.age
# Out:
# 19

# %%
id(fab)
# Out:
# 133584919108272

# %%
id(fab.age)
# Out:
# 133585349690160

# %%
fab.age=91
fab.age
# Out:
# 91

# %%
id(fab) #the id of fab does not change
# Out:
# 133584919108272

# %%
id(fab.age)
# Out:
# 133585349692464

# %%
5/4
# Out:
# 1.25

# %%
5//3 # the double-backslash for interger division
# Out:
# 1

# %%
5/3 # the single-backslash for float division (true division)
# Out:
# 1.6666666666666667

# %%
5%3 # the reminder of division (modulo operator)
# Out:
# 2

# %%
5**3 # 5 to the power of 3
# Out:
# 125

# %%
5*3 # 5 times 3
# Out:
# 15

# %%
-5/3
# Out:
# -1.6666666666666667

# %%
-5//3 # reminder: the result of not like the opposite result of "5//3"
# Out:
# -2

# %%
int(3.9) #used to change a number to an integer, remove the decimal part
# Out:
# 3

# %%
int(-3.1)
# Out:
# -3

# %%
int(3.5)
# Out:
# 3

# %%
int(3.875)
# Out:
# 3

# %%
n=1024
n
# Out:
# 1024

# %%
int(True)
# Out:
# 1

# %%
bool(5)
# Out:
# True

# %%
int(not True)
# Out:
# 0

# %%
>>> int(True) # True behaves like 1
1
>>> int(False) # False behaves like 0
0
>>> bool(1) # 1 evaluates to True in a boolean context
True
>>> bool(-42) # and so does every non-zero number
True
>>> bool(0) # 0 evaluates to False
False
>>> # quick peak at the operators (and, or, not)
>>> not True
False
>>> not False
True
>>> True and True
True
>>> False or True
True

# %%
1+True
# Out:
# 2

# %%
2024-False
# Out:
# 2024

# %%
7*True
# Out:
# 7

# %%
5**True
# Out:
# 5

# %%
pi=3.141592653589793
radius=4 #半径
area=pi*radius**2
area

# %%
pi=3.141592653589793
radius=4 #半径
length=pi*radius*2
length
# Out:
# 25.132741228718345

# %%
import sys
sys.float_info # it shows the range of expressions the system can display the calculations
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
2**64
# Out:
# 18446744073709551616

# %%
0.3-0.1*3 #double precision numbers suffer from approximation issues even when it comes to simple numbers like 0.1 or 0.3.
# Out:
# -5.551115123125783e-17

# %%
c=3.14+59.26j #complex numbers
c
# Out:
# (3.14+59.26j)

# %%
c.real #real part of the complex number
# Out:
# 3.14

# %%
c.imag #imaginary part of the complex number
# Out:
# 59.26

# %%
c.conjugate() #conjugate of the complex number,conjugate of A + Bj is A - Bj
# Out:
# (3.14-59.26j)

# %%
c*0.5
# Out:
# (1.57+29.63j)

# %%
c*0.5j #j=i=(-1)^0.5
# Out:
# (-29.63+1.57j)

# %%
d=1+1j #what's wrong with it?
c+d
# Out:
# (4.140000000000001+60.26j)
