# %%
txt = "Hello my FRIENDS"
x = txt.lower()
print(x)
# Out:
# hello my friends

# %%
myTuple = ("WBS", "UG", "Year 2")
x = "#".join(myTuple) #add separate inbetween the elements'
print(x)
# Out:
# WBS#UG#Year 2

# %%
my_list= [7, 8, 10, 14, 5, 25, 7, 2]
my_list.pop(1) #removes the data with index 1 in the string, which is 8.
print(my_list)
# Out:
# [7, 10, 14, 5, 25, 7, 2]

# %%
print(int(27.7))
# Out:
# 27
