# %%
def calculate (value1, value2=4):
  res = value1* value2
  print(res)

calculate(6, 5)
# Out:
# 30

# %%
listOne = [20, 40, 60, 80]
listTwo = [20, 40, 60, 80]

print(listOne == listTwo)
print(listOne is listTwo)
# Out:
# True
# False

# %%
a, b = 12, 5
if a + b:
    print('True')
else:
  print('False')
# Out:
# True
