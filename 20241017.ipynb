# %%
age=int(input("Age?"))
if age<18:
  print("underage!")
  print("show your ID!")
  print("Finished Checkout")
print("program ends")
# Out:
# Age?19
# program ends

# %%
age=int(input("Age?"))
if age<18:
  print("underage!")
  print("show your ID!")
print("Finished Checkout")
print("program ends")
# Out:
# Age?24
# Finished Checkout
# program ends

# %%
age=int(input("Age?"))
if age<18:
  print("underage!")
     print("show your ID!")
print("Finished Checkout")
# Out:
#   File "<ipython-input-8-1d31d647b24e>", line 4
#     print("show your ID!")
#     ^
# IndentationError: unexpected indent

# %%
age=19
isGraduated=False
hasLicense=True

if age>=18:
  print("A")

  if isGraduated:
    print("B")

  if hasLicense:
      print("C")
  else:
      print("D")
# Out:
# A
# C

# %%
7<10
# Out:
# True
