# %%
x="5"
print(type(x))
# Out:
# <class 'str'>

# %%
cars=["BMW",2000,50.5] #"BMW" is in the 0th position, 2000 is in the 1st position etc.
cars
# Out:
# ['BMW', 2000, 50.5]

# %%
print(type(cars))
# Out:
# <class 'list'>

# %%
cars[1:3]
# Out:
# [2000, 50.5]

# %%
cars[2]=5000

# %%
print(cars)
# Out:
# ['BMW', 2000, 5000]

# %%
DOY="2005"
Current_year=2023
DOY=int(DOY) #change a string to an integer
Current_year=int(Current_year)
print(Current_year-DOY)
# Out:
# 18

# %%
Name=input("what is your name:")
print("Hello",Name,"!")
# Out:
# what is your name:ERC
# Hello ERC !

# %%
77=age
age=77
age=age+1
# Out:
#   File "<ipython-input-29-9c883622b8c7>", line 1
#     77=age
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
