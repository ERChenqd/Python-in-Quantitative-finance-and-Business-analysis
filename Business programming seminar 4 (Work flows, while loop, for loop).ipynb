# %%
#Exercise 1
#Task 1
#Program 1
count = 0
while (count < 3): #':' missed and indentation missed
 count = count + 1
 print("Hello, you are learning to program")
# Out:
# Hello, you are learning to program
# Hello, you are learning to program
# Hello, you are learning to program

# %%
#Program 2
cars = ["tesla", "bmw", "mercedes"]
for x in cars:
 print(x)
 if x == "bmw": #"IN", indentation, ":"
   break
# Out:
# tesla
# bmw

# %%
#Task 2
n=5
while n > 0:
 print(n)
print('Program end!')# this program never ends

# %%
#correction
n=5
while n > 0:
  print(n)
  n-=1
print('Program end!')
# Out:
# 5
# 4
# 3
# 2
# 1
# Program end!

# %%
#Task 3
#Program 2
mail = 0
MAIL = 5
while mail < MAIL:
 print("sending email")
 mail = mail + 1
# Out:
# sending email
# sending email
# sending email
# sending email
# sending email

# %%
#Task 4
companies = ['IBM', 'Apple', 'Microsoft', 'Meta', 'Google'] #Line1
while companies: #Line2 # it will keep doing things until the list is empty
 print(companies.pop()) #Line3
 break # the entire loop terminates, the else part would not run.
else: #Line4
 print('Done.') #Line5
# Out:
# Google

# %%
#Task 5
i = 0
print("Before the loop value of i", i)
for thing in [9, 41, 12, 3, 74, 15] :
 i= i+ 1
 print(i, thing)
print("After the loop value of i", i)
# Out:
# Before the loop value of i 0
# 1 9
# 2 41
# 3 12
# 4 3
# 5 74
# 6 15
# After the loop value of i 6

# %%
#Task 6
sum = 0 #### sum variable initiated to 0
count=0
print("Before the loop the sum is", sum)
for thing in [9, 41, 12, 3, 74, 15] :
 sum= sum+ thing
 count=count+1
 average=sum/count
 print(count, sum, thing)
print ("After the loop the sum and average are",count, sum, average)
# Out:
# Before the loop the sum is 0
# 1 9 9
# 2 50 41
# 3 62 12
# 4 65 3
# 5 139 74
# 6 154 15
# After the loop the sum and average are 6 154 25.666666666666668

# %%
#Task 7
stored_password=["hello"]
recepits=input("Enter a password: ")
while recepits not in stored_password:
  recepits=input("Enter a password: ")
else:
  print("You are logged in, welcome to O2 portal")
# Out:
# Enter a password: hhh
# Enter a password: kkkk

# %%
#Alternative:
password=""
while password!="hello":
  password=input("Enter a password: ")
print("You are logged in, welcome to O2 portal")
# Out:
# Enter a password: lll
# Enter a password: aaaa
# Enter a password: hello
# You are logged in, welcome to O2 portal

# %%
#Exercise 2
#Task 8
persons = [ "John", "Peter", "Vikki", "Henry" ]
places = [ "Spain", "Italy", "India", "UK" ]
for person in persons:
 for place in places:
  print(person, "visits", place)
# Out:
# John visits Spain
# John visits Italy
# John visits India
# John visits UK
# Peter visits Spain
# Peter visits Italy
# Peter visits India
# Peter visits UK
# Vikki visits Spain
# Vikki visits Italy
# Vikki visits India
# Vikki visits UK
# Henry visits Spain
# Henry visits Italy
# Henry visits India
# Henry visits UK
