# %%
list1=[1,2,3]
list2=["1","2","3"]
print(type(list2[2]))
print(type("2"))
# Out:
# <class 'str'>

# %%
cars =["BMW", 2015, 15000]
try4=(cars)
try3=(["BMW","Tesla"])
try2=([1800,"Jerry"])
try1=(1, [1800,"Jerry"], 7, "HSBC")
print(type(try1))
# Out:
# <class 'tuple'>

# %%
print(cars[0])
print(cars[-1])# if we use a negative integer to index, we will start from looking at the right side of the list/turple/dictionary
print(cars[-2])
# Out:
# BMW
# 15000
# 2015

# %%
cars[0]="Tesla"
print(cars)
# Out:
# ['Tesla', 2015, 15000]

# %%
print(len(cars))
print(len(try1[1]))
print(len(try1))
print(len(try2))
# Out:
# 3
# 2
# 4
# 2

# %%
a=[1,2,3]
b=[4,5,6]
c=a+b
print(c)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mytuple = ("wbs")
print(type(mytuple))
mytuple1 = ("wbs",1.5)
print(type(mytuple1))
# Out:
# <class 'str'>
# <class 'tuple'>
